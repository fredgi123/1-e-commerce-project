# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting statsmodels==0.12.2
#   Downloading statsmodels-0.12.2-cp39-cp39-manylinux1_x86_64.whl (9.4 MB)
# Collecting streamlit
#   Downloading streamlit-0.88.0-py2.py3-none-any.whl (8.0 MB)
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Collecting openpyxl
#   Downloading openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
# Collecting pmdarima
#   Downloading pmdarima-1.8.2-cp39-cp39-manylinux1_x86_64.whl (1.4 MB)
# Collecting wordcloud
#   Downloading wordcloud-1.8.1-cp39-cp39-manylinux1_x86_64.whl (363 kB)
# Collecting wget==3.2
#   Downloading wget-3.2.zip (10 kB)
# Requirement already satisfied: tabulate in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 9)) (0.8.9)
# Collecting patsy>=0.5
#   Downloading patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# Requirement already satisfied: numpy>=1.15 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.12.2->-r ./requirements.txt (line 1)) (1.21.2)
# Requirement already satisfied: pandas>=0.21 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.12.2->-r ./requirements.txt (line 1)) (1.2.5)
# Requirement already satisfied: scipy>=1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.12.2->-r ./requirements.txt (line 1)) (1.7.1)
# Collecting watchdog
#   Downloading watchdog-2.1.5-py3-none-manylinux2014_x86_64.whl (75 kB)
# Collecting validators
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Collecting astor
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: requests in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 2)) (2.26.0)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.7.0-py2.py3-none-any.whl (4.3 MB)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.24-py3-none-any.whl (180 kB)
# Collecting tzlocal
#   Downloading tzlocal-3.0-py3-none-any.whl (16 kB)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
# Collecting base58
#   Downloading base58-2.1.0-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: pyarrow in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 2)) (5.0.0)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 2)) (3.18.0)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 2)) (8.3.2)
# Requirement already satisfied: attrs in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 2)) (21.2.0)
# Requirement already satisfied: cachetools>=4.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 2)) (4.2.2)
# Collecting click<8.0,>=7.0
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Requirement already satisfied: altair>=3.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 2)) (4.1.0)
# Requirement already satisfied: python-dateutil in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: packaging in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 2)) (21.0)
# Requirement already satisfied: toml in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 2)) (0.10.2)
# Requirement already satisfied: tornado>=5.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit->-r ./requirements.txt (line 2)) (6.1)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Collecting numpy>=1.15
#   Downloading numpy-1.19.5-cp39-cp39-manylinux2010_x86_64.whl (14.9 MB)
# Requirement already satisfied: urllib3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pmdarima->-r ./requirements.txt (line 5)) (1.26.6)
# Collecting Cython!=0.29.18,>=0.29
#   Downloading Cython-0.29.24-cp39-cp39-manylinux1_x86_64.whl (1.9 MB)
# Requirement already satisfied: joblib>=0.11 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pmdarima->-r ./requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /root/venv/lib/python3.9/site-packages (from pmdarima->-r ./requirements.txt (line 5)) (58.0.4)
# Requirement already satisfied: scikit-learn>=0.22 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pmdarima->-r ./requirements.txt (line 5)) (0.24.2)
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from wordcloud->-r ./requirements.txt (line 6)) (3.4.3)
# Requirement already satisfied: jsonschema in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair>=3.2.0->streamlit->-r ./requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: toolz in /shared-libs/python3.9/py/lib/python3.9/site-packages (from altair>=3.2.0->streamlit->-r ./requirements.txt (line 2)) (0.11.1)
# Requirement already satisfied: entrypoints in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair>=3.2.0->streamlit->-r ./requirements.txt (line 2)) (0.3)
# Requirement already satisfied: jinja2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair>=3.2.0->streamlit->-r ./requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from gitpython!=3.1.19->streamlit->-r ./requirements.txt (line 2)) (3.10.0.2)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=0.21->statsmodels==0.12.2->-r ./requirements.txt (line 1)) (2021.1)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from patsy>=0.5->statsmodels==0.12.2->-r ./requirements.txt (line 1)) (1.16.0)
# Collecting ipywidgets>=7.0.0
#   Downloading ipywidgets-7.6.5-py2.py3-none-any.whl (121 kB)
# Requirement already satisfied: traitlets>=4.3.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (5.1.0)
# Requirement already satisfied: ipykernel>=5.1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (6.3.1)
# Requirement already satisfied: jupyter-client<8.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (7.0.3)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (1.4.3)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (7.27.0)
# Requirement already satisfied: ipython-genutils in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (0.1.3)
# Requirement already satisfied: pickleshare in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: pygments in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (2.10.0)
# Requirement already satisfied: decorator in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (5.1.0)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (4.8.0)
# Requirement already satisfied: backcall in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (0.17.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (3.0.20)
# Requirement already satisfied: nbformat>=4.2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (5.1.3)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.0.2-py3-none-any.whl (243 kB)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2->altair>=3.2.0->streamlit->-r ./requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: pyzmq>=13 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (4.8.1)
# Requirement already satisfied: nest-asyncio>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema->altair>=3.2.0->streamlit->-r ./requirements.txt (line 2)) (0.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pexpect>4.3->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (0.2.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=0.22->pmdarima->-r ./requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: notebook>=4.4.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (7.0.0.dev0)
# Requirement already satisfied: terminado>=0.8.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: nbconvert in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (6.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: argon2-cffi in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (21.1.0)
# Requirement already satisfied: prometheus-client in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: cffi>=1.0.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (1.14.6)
# Requirement already satisfied: pycparser in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (2.20)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->wordcloud->-r ./requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->wordcloud->-r ./requirements.txt (line 6)) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->wordcloud->-r ./requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: testpath in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (0.5.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (0.8.4)
# Requirement already satisfied: defusedxml in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: bleach in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: webencodings in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->-r ./requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests->streamlit->-r ./requirements.txt (line 2)) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests->streamlit->-r ./requirements.txt (line 2)) (2.0.6)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests->streamlit->-r ./requirements.txt (line 2)) (3.2)
# Building wheels for collected packages: wget, blinker
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9672 sha256=72b63099efd0e273a520b4ec44e30f5a299e6d4d8c0ac45667968bb247ccb29a
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
#   Building wheel for blinker (setup.py): started
#   Building wheel for blinker (setup.py): finished with status 'done'
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13478 sha256=a6ae7a093aa70efe1dbccf98b47997f3cd7de1b820480947fe0b27f2099d117a
#   Stored in directory: /root/.cache/pip/wheels/50/93/f8/4f0a42a03a06626d675f13907b6982ad5ecff383530af5a900
# Successfully built wget blinker
# Installing collected packages: widgetsnbextension, smmap, numpy, jupyterlab-widgets, patsy, ipywidgets, gitdb, watchdog, validators, tzlocal, statsmodels, pydeck, gitpython, et-xmlfile, Cython, click, blinker, base58, astor, xlrd, wordcloud, wget, streamlit, pmdarima, openpyxl
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.2
#     Not uninstalling numpy at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'numpy'. No files were found to uninstall.
#   Attempting uninstall: click
#     Found existing installation: click 8.0.1
#     Not uninstalling click at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'click'. No files were found to uninstall.
# Successfully installed Cython-0.29.24 astor-0.8.1 base58-2.1.0 blinker-1.4 click-7.1.2 et-xmlfile-1.1.0 gitdb-4.0.7 gitpython-3.1.24 ipywidgets-7.6.5 jupyterlab-widgets-1.0.2 numpy-1.19.5 openpyxl-3.0.7 patsy-0.5.1 pmdarima-1.8.2 pydeck-0.7.0 smmap-4.0.0 statsmodels-0.12.2 streamlit-0.88.0 tzlocal-3.0 validators-0.18.2 watchdog-2.1.5 wget-3.2 widgetsnbextension-3.5.1 wordcloud-1.8.1 xlrd-2.0.1

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4cc0f255-20f9-4daf-8819-230d4245a6d1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
